# %% [markdown]
# ### Criando classes

# %%
class MinhaClasse():
    pass

# %%
class MinhaClasse():
    def metodo():
        pass

# %%
class MinhaClasse():
    atributo = "valor"
    def metodo():
        pass

# %%
class MinhaClasse():
    def __init__(self):
        self.atributo = "valor"
    def metodo(self):
        pass

# %% [markdown]
# ### Exemplo simples

# %%
class Vendedor():
    pass

# %% [markdown]
# ### Refatorando um código para POO

# %%
# !pip install pyautogui
# Out:
# Requirement already satisfied: pyautogui in /home/gilberto/anaconda3/lib/python3.12/site-packages (0.9.54)
# Requirement already satisfied: python3-Xlib in /home/gilberto/anaconda3/lib/python3.12/site-packages (from pyautogui) (0.15)
# Requirement already satisfied: pymsgbox in /home/gilberto/anaconda3/lib/python3.12/site-packages (from pyautogui) (2.0.1)
# Requirement already satisfied: pytweening>=1.0.4 in /home/gilberto/anaconda3/lib/python3.12/site-packages (from pyautogui) (1.2.0)
# Requirement already satisfied: pyscreeze>=0.1.21 in /home/gilberto/anaconda3/lib/python3.12/site-packages (from pyautogui) (1.0.1)
# Requirement already satisfied: pygetwindow>=0.0.5 in /home/gilberto/anaconda3/lib/python3.12/site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: mouseinfo in /home/gilberto/anaconda3/lib/python3.12/site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pyrect in /home/gilberto/anaconda3/lib/python3.12/site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: pyperclip in /home/gilberto/anaconda3/lib/python3.12/site-packages (from mouseinfo->pyautogui) (1.11.0)

# %%
import pyautogui
import pyperclip
import time

# abrindo o chrome
pyautogui.PAUSE = 1
pyautogui.press("win")
pyautogui.write("chrome")
pyautogui.press("enter")

# entrando no site da hashtag
link = "https://www.hashtagtreinamentos.com/blog"
pyperclip.copy(link)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

# aguardar
time.sleep(3)

# clicando no campo de busca
pyautogui.click(x=1508, y=585)

# pesquisando campo de busca
texto = "classe"
pyperclip.copy(texto)
pyautogui.hotkey("ctrl",
                 "v")
pyautogui.press("enter")

# aguardar
time.sleep(3)

# clicar na imagem
pyautogui.click(x=749, y=699)

# aguardar
time.sleep(3)

# extrair o link
pyautogui.click(x=390, y=789, button="right")
pyautogui.press("up")
pyautogui.press("up")
pyautogui.press("enter")
http://127.0.0.1:8888/tree?token=10fe70a7aa06f52d9fccb8900b666f345c22706c60577bbc

# printar o texto copiado
texto = pyperclip.paste()
print(texto)
# Out:
# QXcbClipboard::setMimeData: Cannot set X11 selection owner
# QXcbClipboard::setMimeData: Cannot set X11 selection owner
# http://127.0.0.1:8888/tree?token=10fe70a7aa06f52d9fccb8900b666f345c22706c60577bbc

# %% [markdown]
# # http://127.0.0.1:8888/tree?token=10fe70a7aa06f52d9fccb8900b666f345c22706c60577bbc
# pegando a posicao de um elemento
# for i in range(5):
#     print(f"pegando posicao em {5 - i} segundos")
#     time.sleep(1)
#
# print(pyautogui.position())

# %% [markdown]
# ### Refatorando com classe
